# %%
from fastai import *
from fastai.vision import *

import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import auc,roc_curve

# %%
import os
print(os.listdir("../input"))

% matplotlib inline
# Out:
# ['hmnist_64_64_L.csv', 'Kather_texture_2016_larger_images_10', 'kather_texture_2016_larger_images_10', 'hmnist_8_8_RGB.csv', 'hmnist_28_28_RGB.csv', 'hmnist_8_8_L.csv', 'Kather_texture_2016_image_tiles_5000', 'kather_texture_2016_image_tiles_5000', 'hmnist_28_28_L.csv']

# %%
path= Path('../input/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/')
csv_file='../input/hmnist_28_28_RGB.csv'

# %%
df= pd.read_csv(csv_file)
df.head()
# Out:
#    pixel0000  pixel0001  pixel0002  ...    pixel2350  pixel2351  label
# 0        156         73        106  ...          137        172      2
# 1        139         33         55  ...           38         60      2
# 2        186         96        135  ...           66        108      2
# 3        139         50         84  ...           34         63      2
# 4        197        130        162  ...          132        165      2
#
# [5 rows x 2353 columns]

# %%
class_names = {1: "Tumor", 2: "Stroma", 3: "Complex", 4: "Lympho",
               5: "Debris", 6: "Mucosa", 7: "Adipose", 8: "Empty"}
class_numbers = {"Tumor": 1, "Stroma": 2, "Complex": 3, "Lympho": 4,
               "Debris": 5, "Mucosa": 6, "Adipose": 7, "Empty": 8}
class_colors = {1: "Red", 2: "Orange", 3: "Gold", 4: "Limegreen",
                5: "Mediumseagreen", 6: "Darkturquoise", 7: "Steelblue", 8: "Purple"}

label_percentage = df.label.value_counts() / df.shape[0]
class_index = [class_names[idx] for idx in label_percentage.index.values]

plt.figure(figsize=(20,5))
sns.barplot(x=class_index, y=label_percentage.values, palette="Set3");
plt.ylabel("% in data");
plt.xlabel("Target cancer class");
plt.title("How is cancer distributed in this data?");

# %%
tfms=get_transforms(flip_vert=True, max_warp=0.)

# %%
data = (ImageItemList.from_folder(path)
        .random_split_by_pct()
        .label_from_folder()
        .transform(tfms, size=150)
        .databunch(num_workers=2, bs=32))

# %%
data.show_batch(row=3, figsize=(10,10))

# %% [markdown]
# ## Model

# %% [markdown]
# **CNN**

# %%
learner= create_cnn(data, models.resnet34, metrics=[accuracy], model_dir='/tmp/models/')
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.torch/models/resnet34-333f7ec4.pth
# 100%|██████████| 87306240/87306240 [00:03<00:00, 26680697.04it/s]

# %%
learner.lr_find()
learner.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %% [markdown]
# ****Learning rate = 0.001****

# %%
lr=0.001
learner.fit_one_cycle(50, lr)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='47' class='' max='50', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       94.00% [47/50 15:49<01:00]
#     </div>
#
# <table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.812172</th>
#     <th>1.243875</th>
#     <th>0.607000</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>1.263186</th>
#     <th>0.788107</th>
#     <th>0.768000</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.875537</th>
#     <th>0.514965</th>
#     <th>0.853000</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.650535</th>
#     <th>0.374563</th>
#     <th>0.879000</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.543242</th>
#     <th>0.312203</th>
#     <th>0.898000</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.449925</th>
#     <th>0.263908</th>
#     <th>0.913000</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.367982</th>
#     <th>0.243029</th>
#     <th>0.916000</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.341768</th>
#     <th>0.232865</th>
#     <th>0.927000</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.325466</th>
#     <th>0.229844</th>
#     <th>0.928000</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.285479</th>
#     <th>0.212894</th>
#     <th>0.925000</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>0.270901</th>
#     <th>0.203381</th>
#     <th>0.930000</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>0.257444</th>
#     <th>0.177387</th>
#     <th>0.937000</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>0.250659</th>
#     <th>0.173453</th>
#     <th>0.939000</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>0.225546</th>
#     <th>0.176565</th>
#     <th>0.937000</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>0.210774</th>
#     <th>0.173897</th>
#     <th>0.946000</th>
#   </tr>
#   <tr>
#     <th>16</th>
#     <th>0.214513</th>
#     <th>0.158844</th>
#     <th>0.956000</th>
#   </tr>
#   <tr>
#     <th>17</th>
#     <th>0.211037</th>
#     <th>0.158152</th>
#     <th>0.951000</th>
#   </tr>
#   <tr>
#     <th>18</th>
#     <th>0.191406</th>
#     <th>0.175946</th>
#     <th>0.952000</th>
#   </tr>
#   <tr>
#     <th>19</th>
#     <th>0.178223</th>
#     <th>0.162221</th>
#     <th>0.949000</th>
#   </tr>
#   <tr>
#     <th>20</th>
#     <th>0.169287</th>
#     <th>0.150089</th>
#     <th>0.958000</th>
#   </tr>
#   <tr>
#     <th>21</th>
#     <th>0.169328</th>
#     <th>0.148419</th>
#     <th>0.955000</th>
#   </tr>
#   <tr>
#     <th>22</th>
#     <th>0.162781</th>
#     <th>0.151613</th>
#     <th>0.956000</th>
#   </tr>
#   <tr>
#     <th>23</th>
#     <th>0.155517</th>
#     <th>0.147632</th>
#     <th>0.957000</th>
#   </tr>
#   <tr>
#     <th>24</th>
#     <th>0.142785</th>
#     <th>0.143929</th>
#     <th>0.963000</th>
#   </tr>
#   <tr>
#     <th>25</th>
#     <th>0.166804</th>
#     <th>0.146641</th>
#     <th>0.962000</th>
#   </tr>
#   <tr>
#     <th>26</th>
#     <th>0.137509</th>
#     <th>0.140500</th>
#     <th>0.960000</th>
#   </tr>
#   <tr>
#     <th>27</th>
#     <th>0.144777</th>
#     <th>0.161439</th>
#     <th>0.954000</th>
#   </tr>
#   <tr>
#     <th>28</th>
#     <th>0.122345</th>
#     <th>0.144732</th>
#     <th>0.958000</th>
#   </tr>
#   <tr>
#     <th>29</th>
#     <th>0.127028</th>
#     <th>0.141664</th>
#     <th>0.960000</th>
#   </tr>
#   <tr>
#     <th>30</th>
#     <th>0.132206</th>
#     <th>0.154537</th>
#     <th>0.958000</th>
#   </tr>
#   <tr>
#     <th>31</th>
#     <th>0.116316</th>
#     <th>0.157924</th>
#     <th>0.957000</th>
#   </tr>
#   <tr>
#     <th>32</th>
#     <th>0.128173</th>
#     <th>0.145070</th>
#     <th>0.957000</th>
#   </tr>
#   <tr>
#     <th>33</th>
#     <th>0.126595</th>
#     <th>0.135866</th>
#     <th>0.960000</th>
#   </tr>
#   <tr>
#     <th>34</th>
#     <th>0.119946</th>
#     <th>0.146720</th>
#     <th>0.955000</th>
#   </tr>
#   <tr>
#     <th>35</th>
#     <th>0.098862</th>
#     <th>0.142287</th>
#     <th>0.964000</th>
#   </tr>
#   <tr>
#     <th>36</th>
#     <th>0.104256</th>
#     <th>0.144704</th>
#     <th>0.956000</th>
#   </tr>
#   <tr>
#     <th>37</th>
#     <th>0.114337</th>
#     <th>0.141641</th>
#     <th>0.954000</th>
#   </tr>
#   <tr>
#     <th>38</th>
#     <th>0.110612</th>
#     <th>0.127076</th>
#     <th>0.964000</th>
#   </tr>
#   <tr>
#     <th>39</th>
#     <th>0.099604</th>
#     <th>0.128564</th>
#     <th>0.962000</th>
#   </tr>
#   <tr>
#     <th>40</th>
#     <th>0.090223</th>
#     <th>0.139084</th>
#     <th>0.956000</th>
#   </tr>
#   <tr>
#     <th>41</th>
#     <th>0.098351</th>
#     <th>0.139206</th>
#     <th>0.958000</th>
#   </tr>
#   <tr>
#     <th>42</th>
#     <th>0.084995</th>
#     <th>0.133945</th>
#     <th>0.959000</th>
#   </tr>
#   <tr>
#     <th>43</th>
#     <th>0.081656</th>
#     <th>0.137599</th>
#     <th>0.960000</th>
#   </tr>
#   <tr>
#     <th>44</th>
#     <th>0.082493</th>
#     <th>0.129634</th>
#     <th>0.960000</th>
#   </tr>
#   <tr>
#     <th>45</th>
#     <th>0.091266</th>
#     <th>0.133583</th>
#     <th>0.961000</th>
#   </tr>
#   <tr>
#     <th>46</th>
#     <th>0.086012</th>
#     <th>0.128843</th>
#     <th>0.963000</th>
#   </tr>
#   <tr>
#     <th>47</th>
#     <th>0.098483</th>
#     <th>0.132403</th>
#     <th>0.960000</th>
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='24' class='' max='32', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       75.00% [24/32 00:02<00:00]
#     </div>

# %%
learner.save('stage-1')

# %%
learner.unfreeze()

# %%
learner.lr_find()
learner.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learner.fit_one_cycle(50,  6.25e-6)
# Out:
# Total time: 17:24 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.085678</th>
#     <th>0.135206</th>
#     <th>0.963000</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.082056</th>
#     <th>0.128296</th>
#     <th>0.965000</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.086163</th>
#     <th>0.128978</th>
#     <th>0.961000</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.076432</th>
#     <th>0.133299</th>
#     <th>0.962000</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.089315</th>
#     <th>0.134296</th>
#     <th>0.961000</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.086260</th>
#     <th>0.133757</th>
#     <th>0.965000</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.083168</th>
#     <th>0.138649</th>
#     <th>0.963000</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.080868</th>
#     <th>0.131486</th>
#     <th>0.962000</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.087750</th>
#     <th>0.132908</th>
#     <th>0.959000</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.077813</th>
#     <th>0.131903</th>
#     <th>0.963000</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>0.087574</th>
#     <th>0.132553</th>
#     <th>0.965000</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>0.088509</th>
#     <th>0.130919</th>
#     <th>0.963000</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>0.076147</th>
#     <th>0.129806</th>
#     <th>0.961000</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>0.081582</th>
#     <th>0.127345</th>
#     <th>0.964000</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>0.072982</th>
#     <th>0.134285</th>
#     <th>0.962000</th>
#   </tr>
#   <tr>
#     <th>16</th>
#     <th>0.077728</th>
#     <th>0.136859</th>
#     <th>0.962000</th>
#   </tr>
#   <tr>
#     <th>17</th>
#     <th>0.075649</th>
#     <th>0.133836</th>
#     <th>0.963000</th>
#   </tr>
#   <tr>
#     <th>18</th>
#     <th>0.081404</th>
#     <th>0.127420</th>
#     <th>0.963000</th>
#   </tr>
#   <tr>
#     <th>19</th>
#     <th>0.077476</th>
#     <th>0.138879</th>
#     <th>0.960000</th>
#   </tr>
#   <tr>
#     <th>20</th>
#     <th>0.061890</th>
#     <th>0.121727</th>
#     <th>0.964000</th>
#   </tr>
#   <tr>
#     <th>21</th>
#     <th>0.074529</th>
#     <th>0.130958</th>
#     <th>0.962000</th>
#   </tr>
#   <tr>
#     <th>22</th>
#     <th>0.072552</th>
#     <th>0.129895</th>
#     <th>0.962000</th>
#   </tr>
#   <tr>
#     <th>23</th>
#     <th>0.061530</th>
#     <th>0.136346</th>
#     <th>0.963000</th>
#   </tr>
#   <tr>
#     <th>24</th>
#     <th>0.059298</th>
#     <th>0.131200</th>
#     <th>0.962000</th>
#   </tr>
#   <tr>
#     <th>25</th>
#     <th>0.060846</th>
#     <th>0.126992</th>
#     <th>0.963000</th>
#   </tr>
#   <tr>
#     <th>26</th>
#     <th>0.067214</th>
#     <th>0.133569</th>
#     <th>0.964000</th>
#   </tr>
#   <tr>
#     <th>27</th>
#     <th>0.054779</th>
#     <th>0.133284</th>
#     <th>0.965000</th>
#   </tr>
#   <tr>
#     <th>28</th>
#     <th>0.054868</th>
#     <th>0.124685</th>
#     <th>0.963000</th>
#   </tr>
#   <tr>
#     <th>29</th>
#     <th>0.055673</th>
#     <th>0.134967</th>
#     <th>0.960000</th>
#   </tr>
#   <tr>
#     <th>30</th>
#     <th>0.052469</th>
#     <th>0.128257</th>
#     <th>0.963000</th>
#   </tr>
#   <tr>
#     <th>31</th>
#     <th>0.056666</th>
#     <th>0.137942</th>
#     <th>0.963000</th>
#   </tr>
#   <tr>
#     <th>32</th>
#     <th>0.055768</th>
#     <th>0.141973</th>
#     <th>0.958000</th>
#   </tr>
#   <tr>
#     <th>33</th>
#     <th>0.045637</th>
#     <th>0.136978</th>
#     <th>0.959000</th>
#   </tr>
#   <tr>
#     <th>34</th>
#     <th>0.048422</th>
#     <th>0.127309</th>
#     <th>0.963000</th>
#   </tr>
#   <tr>
#     <th>35</th>
#     <th>0.046153</th>
#     <th>0.125628</th>
#     <th>0.962000</th>
#   </tr>
#   <tr>
#     <th>36</th>
#     <th>0.046513</th>
#     <th>0.135347</th>
#     <th>0.961000</th>
#   </tr>
#   <tr>
#     <th>37</th>
#     <th>0.050253</th>
#     <th>0.130707</th>
#     <th>0.961000</th>
#   </tr>
#   <tr>
#     <th>38</th>
#     <th>0.044907</th>
#     <th>0.129023</th>
#     <th>0.963000</th>
#   </tr>
#   <tr>
#     <th>39</th>
#     <th>0.045279</th>
#     <th>0.133678</th>
#     <th>0.960000</th>
#   </tr>
#   <tr>
#     <th>40</th>
#     <th>0.055506</th>
#     <th>0.131521</th>
#     <th>0.964000</th>
#   </tr>
#   <tr>
#     <th>41</th>
#     <th>0.050969</th>
#     <th>0.129497</th>
#     <th>0.960000</th>
#   </tr>
#   <tr>
#     <th>42</th>
#     <th>0.043192</th>
#     <th>0.125283</th>
#     <th>0.963000</th>
#   </tr>
#   <tr>
#     <th>43</th>
#     <th>0.043853</th>
#     <th>0.128406</th>
#     <th>0.960000</th>
#   </tr>
#   <tr>
#     <th>44</th>
#     <th>0.046456</th>
#     <th>0.130221</th>
#     <th>0.961000</th>
#   </tr>
#   <tr>
#     <th>45</th>
#     <th>0.045403</th>
#     <th>0.130905</th>
#     <th>0.961000</th>
#   </tr>
#   <tr>
#     <th>46</th>
#     <th>0.051777</th>
#     <th>0.130132</th>
#     <th>0.963000</th>
#   </tr>
#   <tr>
#     <th>47</th>
#     <th>0.037752</th>
#     <th>0.128125</th>
#     <th>0.962000</th>
#   </tr>
#   <tr>
#     <th>48</th>
#     <th>0.045839</th>
#     <th>0.130670</th>
#     <th>0.964000</th>
#   </tr>
#   <tr>
#     <th>49</th>
#     <th>0.049131</th>
#     <th>0.130475</th>
#     <th>0.962000</th>
#   </tr>
#   <tr>
#     <th>50</th>
#     <th>0.047266</th>
#     <th>0.130181</th>
#     <th>0.963000</th>
#   </tr>
# </table>

# %%
learner.recorder.plot_losses()

# %%
learner.save('stage-2')

# %% [markdown]
# ## Evaluation

# %%
interp = ClassificationInterpretation.from_learner(learner)
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused()
# Out:
# [('02_STROMA', '03_COMPLEX', 8),
#  ('03_COMPLEX', '04_LYMPHO', 4),
#  ('07_ADIPOSE', '08_EMPTY', 4),
#  ('03_COMPLEX', '02_STROMA', 3),
#  ('04_LYMPHO', '03_COMPLEX', 3),
#  ('05_DEBRIS', '02_STROMA', 3),
#  ('01_TUMOR', '03_COMPLEX', 2),
#  ('02_STROMA', '05_DEBRIS', 2),
#  ('03_COMPLEX', '01_TUMOR', 2)]

# %%
preds, lb=learner.get_preds()

# %%
#  ROC curve
fpr, tpr, thresholds = roc_curve(lb.numpy(), preds.numpy()[:,1], pos_label=1)

#  ROC area
pred_score = auc(fpr, tpr)
print(f'ROC area is {pred_score}')
# Out:
# ROC area is 0.9972417185674505

# %%
plt.figure()
plt.plot(fpr, tpr, color='orange', label='ROC curve (area = %0.2f)' % pred_score)
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlim([-0.01, 1.0])
plt.ylim([0.0, 1.01])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")

# %% [markdown]
# **Learning rate = 0.005**

# %%
lr=0.005
learner.fit_one_cycle(50, lr)
# Out:
# Total time: 17:31 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.415301</th>
#     <th>0.354401</th>
#     <th>0.904000</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.367021</th>
#     <th>0.374958</th>
#     <th>0.873000</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.355424</th>
#     <th>0.624386</th>
#     <th>0.819000</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.490265</th>
#     <th>0.579926</th>
#     <th>0.827000</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.411538</th>
#     <th>1.049214</th>
#     <th>0.742000</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.535740</th>
#     <th>1.489944</th>
#     <th>0.608000</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.516634</th>
#     <th>1.000115</th>
#     <th>0.617000</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.701828</th>
#     <th>0.593610</th>
#     <th>0.774000</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.853006</th>
#     <th>0.764027</th>
#     <th>0.684000</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.779638</th>
#     <th>1.119647</th>
#     <th>0.711000</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>0.634442</th>
#     <th>0.531395</th>
#     <th>0.798000</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>0.788502</th>
#     <th>1.586326</th>
#     <th>0.653000</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>0.831372</th>
#     <th>0.760608</th>
#     <th>0.689000</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>0.685674</th>
#     <th>0.469382</th>
#     <th>0.816000</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>0.635711</th>
#     <th>0.506396</th>
#     <th>0.812000</th>
#   </tr>
#   <tr>
#     <th>16</th>
#     <th>0.626835</th>
#     <th>0.866488</th>
#     <th>0.693000</th>
#   </tr>
#   <tr>
#     <th>17</th>
#     <th>0.597761</th>
#     <th>0.436373</th>
#     <th>0.852000</th>
#   </tr>
#   <tr>
#     <th>18</th>
#     <th>0.532899</th>
#     <th>0.526755</th>
#     <th>0.806000</th>
#   </tr>
#   <tr>
#     <th>19</th>
#     <th>0.512298</th>
#     <th>2.545298</th>
#     <th>0.514000</th>
#   </tr>
#   <tr>
#     <th>20</th>
#     <th>0.479439</th>
#     <th>0.614265</th>
#     <th>0.783000</th>
#   </tr>
#   <tr>
#     <th>21</th>
#     <th>0.481206</th>
#     <th>0.428174</th>
#     <th>0.836000</th>
#   </tr>
#   <tr>
#     <th>22</th>
#     <th>0.456288</th>
#     <th>0.636106</th>
#     <th>0.834000</th>
#   </tr>
#   <tr>
#     <th>23</th>
#     <th>0.436323</th>
#     <th>0.665220</th>
#     <th>0.791000</th>
#   </tr>
#   <tr>
#     <th>24</th>
#     <th>0.397613</th>
#     <th>0.819154</th>
#     <th>0.744000</th>
#   </tr>
#   <tr>
#     <th>25</th>
#     <th>0.394517</th>
#     <th>0.323761</th>
#     <th>0.885000</th>
#   </tr>
#   <tr>
#     <th>26</th>
#     <th>0.380153</th>
#     <th>0.368828</th>
#     <th>0.864000</th>
#   </tr>
#   <tr>
#     <th>27</th>
#     <th>0.363555</th>
#     <th>0.415268</th>
#     <th>0.854000</th>
#   </tr>
#   <tr>
#     <th>28</th>
#     <th>0.387028</th>
#     <th>0.520906</th>
#     <th>0.845000</th>
#   </tr>
#   <tr>
#     <th>29</th>
#     <th>0.344560</th>
#     <th>0.340466</th>
#     <th>0.889000</th>
#   </tr>
#   <tr>
#     <th>30</th>
#     <th>0.316991</th>
#     <th>0.907324</th>
#     <th>0.834000</th>
#   </tr>
#   <tr>
#     <th>31</th>
#     <th>0.314994</th>
#     <th>0.751571</th>
#     <th>0.868000</th>
#   </tr>
#   <tr>
#     <th>32</th>
#     <th>0.306681</th>
#     <th>0.433794</th>
#     <th>0.897000</th>
#   </tr>
#   <tr>
#     <th>33</th>
#     <th>0.258377</th>
#     <th>0.258810</th>
#     <th>0.917000</th>
#   </tr>
#   <tr>
#     <th>34</th>
#     <th>0.273815</th>
#     <th>0.333043</th>
#     <th>0.900000</th>
#   </tr>
#   <tr>
#     <th>35</th>
#     <th>0.263849</th>
#     <th>0.209044</th>
#     <th>0.933000</th>
#   </tr>
#   <tr>
#     <th>36</th>
#     <th>0.247558</th>
#     <th>0.494689</th>
#     <th>0.859000</th>
#   </tr>
#   <tr>
#     <th>37</th>
#     <th>0.231921</th>
#     <th>0.524607</th>
#     <th>0.926000</th>
#   </tr>
#   <tr>
#     <th>38</th>
#     <th>0.216029</th>
#     <th>0.640932</th>
#     <th>0.901000</th>
#   </tr>
#   <tr>
#     <th>39</th>
#     <th>0.220774</th>
#     <th>0.294364</th>
#     <th>0.915000</th>
#   </tr>
#   <tr>
#     <th>40</th>
#     <th>0.226835</th>
#     <th>0.427543</th>
#     <th>0.918000</th>
#   </tr>
#   <tr>
#     <th>41</th>
#     <th>0.202279</th>
#     <th>0.223043</th>
#     <th>0.930000</th>
#   </tr>
#   <tr>
#     <th>42</th>
#     <th>0.221147</th>
#     <th>0.543107</th>
#     <th>0.927000</th>
#   </tr>
#   <tr>
#     <th>43</th>
#     <th>0.193721</th>
#     <th>0.248361</th>
#     <th>0.936000</th>
#   </tr>
#   <tr>
#     <th>44</th>
#     <th>0.185006</th>
#     <th>0.248000</th>
#     <th>0.934000</th>
#   </tr>
#   <tr>
#     <th>45</th>
#     <th>0.187381</th>
#     <th>0.247086</th>
#     <th>0.939000</th>
#   </tr>
#   <tr>
#     <th>46</th>
#     <th>0.197599</th>
#     <th>0.380940</th>
#     <th>0.933000</th>
#   </tr>
#   <tr>
#     <th>47</th>
#     <th>0.167779</th>
#     <th>0.178292</th>
#     <th>0.945000</th>
#   </tr>
#   <tr>
#     <th>48</th>
#     <th>0.171584</th>
#     <th>0.220222</th>
#     <th>0.938000</th>
#   </tr>
#   <tr>
#     <th>49</th>
#     <th>0.161294</th>
#     <th>0.321890</th>
#     <th>0.931000</th>
#   </tr>
#   <tr>
#     <th>50</th>
#     <th>0.161621</th>
#     <th>0.388297</th>
#     <th>0.931000</th>
#   </tr>
# </table>

# %%
learner.save('stage-3')

# %%
learner.unfreeze()

# %%
learner.lr_find()
learner.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learner.fit_one_cycle(50,  3.125e-5)
# Out:
# Total time: 17:49 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.168210</th>
#     <th>0.383210</th>
#     <th>0.939000</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.167684</th>
#     <th>0.244416</th>
#     <th>0.938000</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.178902</th>
#     <th>0.460000</th>
#     <th>0.931000</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.174983</th>
#     <th>0.259975</th>
#     <th>0.937000</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.183297</th>
#     <th>0.278197</th>
#     <th>0.939000</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.165569</th>
#     <th>0.212491</th>
#     <th>0.941000</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.175770</th>
#     <th>0.355112</th>
#     <th>0.934000</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.158114</th>
#     <th>0.576553</th>
#     <th>0.934000</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.175925</th>
#     <th>0.303504</th>
#     <th>0.935000</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.178559</th>
#     <th>0.358839</th>
#     <th>0.935000</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>0.168801</th>
#     <th>0.277479</th>
#     <th>0.934000</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>0.170442</th>
#     <th>0.262425</th>
#     <th>0.941000</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>0.163624</th>
#     <th>0.492809</th>
#     <th>0.934000</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>0.167914</th>
#     <th>0.195572</th>
#     <th>0.940000</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>0.173298</th>
#     <th>0.240448</th>
#     <th>0.938000</th>
#   </tr>
#   <tr>
#     <th>16</th>
#     <th>0.170789</th>
#     <th>0.435077</th>
#     <th>0.930000</th>
#   </tr>
#   <tr>
#     <th>17</th>
#     <th>0.169864</th>
#     <th>0.245866</th>
#     <th>0.938000</th>
#   </tr>
#   <tr>
#     <th>18</th>
#     <th>0.165479</th>
#     <th>0.245651</th>
#     <th>0.936000</th>
#   </tr>
#   <tr>
#     <th>19</th>
#     <th>0.169619</th>
#     <th>0.287804</th>
#     <th>0.935000</th>
#   </tr>
#   <tr>
#     <th>20</th>
#     <th>0.168525</th>
#     <th>0.278991</th>
#     <th>0.934000</th>
#   </tr>
#   <tr>
#     <th>21</th>
#     <th>0.159190</th>
#     <th>0.360956</th>
#     <th>0.929000</th>
#   </tr>
#   <tr>
#     <th>22</th>
#     <th>0.167074</th>
#     <th>0.375787</th>
#     <th>0.933000</th>
#   </tr>
#   <tr>
#     <th>23</th>
#     <th>0.161337</th>
#     <th>0.237501</th>
#     <th>0.940000</th>
#   </tr>
#   <tr>
#     <th>24</th>
#     <th>0.159411</th>
#     <th>0.202977</th>
#     <th>0.941000</th>
#   </tr>
#   <tr>
#     <th>25</th>
#     <th>0.170203</th>
#     <th>0.218614</th>
#     <th>0.944000</th>
#   </tr>
#   <tr>
#     <th>26</th>
#     <th>0.167486</th>
#     <th>0.260428</th>
#     <th>0.938000</th>
#   </tr>
#   <tr>
#     <th>27</th>
#     <th>0.166124</th>
#     <th>0.550523</th>
#     <th>0.936000</th>
#   </tr>
#   <tr>
#     <th>28</th>
#     <th>0.174650</th>
#     <th>0.233214</th>
#     <th>0.941000</th>
#   </tr>
#   <tr>
#     <th>29</th>
#     <th>0.163061</th>
#     <th>0.211453</th>
#     <th>0.938000</th>
#   </tr>
#   <tr>
#     <th>30</th>
#     <th>0.172818</th>
#     <th>0.307762</th>
#     <th>0.938000</th>
#   </tr>
#   <tr>
#     <th>31</th>
#     <th>0.158632</th>
#     <th>0.341717</th>
#     <th>0.935000</th>
#   </tr>
#   <tr>
#     <th>32</th>
#     <th>0.157765</th>
#     <th>0.255755</th>
#     <th>0.938000</th>
#   </tr>
#   <tr>
#     <th>33</th>
#     <th>0.152774</th>
#     <th>0.239374</th>
#     <th>0.942000</th>
#   </tr>
#   <tr>
#     <th>34</th>
#     <th>0.154156</th>
#     <th>0.247764</th>
#     <th>0.939000</th>
#   </tr>
#   <tr>
#     <th>35</th>
#     <th>0.171313</th>
#     <th>0.239488</th>
#     <th>0.942000</th>
#   </tr>
#   <tr>
#     <th>36</th>
#     <th>0.164049</th>
#     <th>0.301177</th>
#     <th>0.935000</th>
#   </tr>
#   <tr>
#     <th>37</th>
#     <th>0.158363</th>
#     <th>0.249294</th>
#     <th>0.938000</th>
#   </tr>
#   <tr>
#     <th>38</th>
#     <th>0.173404</th>
#     <th>0.248057</th>
#     <th>0.934000</th>
#   </tr>
#   <tr>
#     <th>39</th>
#     <th>0.167985</th>
#     <th>0.330580</th>
#     <th>0.936000</th>
#   </tr>
#   <tr>
#     <th>40</th>
#     <th>0.157462</th>
#     <th>0.381149</th>
#     <th>0.932000</th>
#   </tr>
#   <tr>
#     <th>41</th>
#     <th>0.164931</th>
#     <th>0.897647</th>
#     <th>0.933000</th>
#   </tr>
#   <tr>
#     <th>42</th>
#     <th>0.162191</th>
#     <th>0.211978</th>
#     <th>0.939000</th>
#   </tr>
#   <tr>
#     <th>43</th>
#     <th>0.152010</th>
#     <th>0.269800</th>
#     <th>0.942000</th>
#   </tr>
#   <tr>
#     <th>44</th>
#     <th>0.155361</th>
#     <th>0.559145</th>
#     <th>0.932000</th>
#   </tr>
#   <tr>
#     <th>45</th>
#     <th>0.163197</th>
#     <th>0.338146</th>
#     <th>0.937000</th>
#   </tr>
#   <tr>
#     <th>46</th>
#     <th>0.170721</th>
#     <th>0.346075</th>
#     <th>0.933000</th>
#   </tr>
#   <tr>
#     <th>47</th>
#     <th>0.156125</th>
#     <th>0.239099</th>
#     <th>0.941000</th>
#   </tr>
#   <tr>
#     <th>48</th>
#     <th>0.163490</th>
#     <th>0.257722</th>
#     <th>0.942000</th>
#   </tr>
#   <tr>
#     <th>49</th>
#     <th>0.165082</th>
#     <th>0.234530</th>
#     <th>0.938000</th>
#   </tr>
#   <tr>
#     <th>50</th>
#     <th>0.162681</th>
#     <th>0.418180</th>
#     <th>0.928000</th>
#   </tr>
# </table>

# %%
learner.recorder.plot_losses()

# %%
learner.save('stage-4')

# %% [markdown]
# **Evaluation**

# %%
interp = ClassificationInterpretation.from_learner(learner)
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused()
# Out:
# [('02_STROMA', '03_COMPLEX', 16),
#  ('05_DEBRIS', '06_MUCOSA', 12),
#  ('05_DEBRIS', '02_STROMA', 9),
#  ('02_STROMA', '05_DEBRIS', 5),
#  ('03_COMPLEX', '04_LYMPHO', 5),
#  ('07_ADIPOSE', '08_EMPTY', 5),
#  ('01_TUMOR', '03_COMPLEX', 4),
#  ('02_STROMA', '04_LYMPHO', 3),
#  ('03_COMPLEX', '02_STROMA', 3),
#  ('04_LYMPHO', '03_COMPLEX', 3)]

# %%
preds, lb=learner.get_preds()

# %%
#  ROC curve
fpr, tpr, thresholds = roc_curve(lb.numpy(), preds.numpy()[:,1], pos_label=1)

#  ROC area
pred_score = auc(fpr, tpr)
print(f'ROC area is {pred_score}')
# Out:
# ROC area is 0.9789966531680707

# %%
plt.figure()
plt.plot(fpr, tpr, color='orange', label='ROC curve (area = %0.2f)' % pred_score)
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlim([-0.01, 1.0])
plt.ylim([0.0, 1.01])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")

# %% [markdown]
# **Learning rate = 0.01**

# %%
lr=0.01
learner.fit_one_cycle(50, lr)
# Out:
# Total time: 16:41 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.738624</th>
#     <th>0.354445</th>
#     <th>0.883000</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.476821</th>
#     <th>0.251008</th>
#     <th>0.915000</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.378217</th>
#     <th>0.230433</th>
#     <th>0.916000</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.348202</th>
#     <th>0.227974</th>
#     <th>0.924000</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.330236</th>
#     <th>0.205496</th>
#     <th>0.919000</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.334911</th>
#     <th>0.204721</th>
#     <th>0.920000</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.353959</th>
#     <th>0.339721</th>
#     <th>0.877000</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.339587</th>
#     <th>0.325151</th>
#     <th>0.886000</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.342025</th>
#     <th>0.275849</th>
#     <th>0.912000</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.342926</th>
#     <th>0.566805</th>
#     <th>0.834000</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>0.350875</th>
#     <th>0.378433</th>
#     <th>0.873000</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>0.351974</th>
#     <th>0.268815</th>
#     <th>0.906000</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>0.335051</th>
#     <th>0.346642</th>
#     <th>0.893000</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>0.334169</th>
#     <th>0.359058</th>
#     <th>0.877000</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>0.359449</th>
#     <th>0.302923</th>
#     <th>0.900000</th>
#   </tr>
#   <tr>
#     <th>16</th>
#     <th>0.347739</th>
#     <th>0.223549</th>
#     <th>0.926000</th>
#   </tr>
#   <tr>
#     <th>17</th>
#     <th>0.339275</th>
#     <th>0.200107</th>
#     <th>0.930000</th>
#   </tr>
#   <tr>
#     <th>18</th>
#     <th>0.275991</th>
#     <th>0.329802</th>
#     <th>0.899000</th>
#   </tr>
#   <tr>
#     <th>19</th>
#     <th>0.288713</th>
#     <th>0.325437</th>
#     <th>0.889000</th>
#   </tr>
#   <tr>
#     <th>20</th>
#     <th>0.271269</th>
#     <th>0.261555</th>
#     <th>0.930000</th>
#   </tr>
#   <tr>
#     <th>21</th>
#     <th>0.250478</th>
#     <th>0.255049</th>
#     <th>0.925000</th>
#   </tr>
#   <tr>
#     <th>22</th>
#     <th>0.286213</th>
#     <th>0.195290</th>
#     <th>0.933000</th>
#   </tr>
#   <tr>
#     <th>23</th>
#     <th>0.283509</th>
#     <th>0.237420</th>
#     <th>0.934000</th>
#   </tr>
#   <tr>
#     <th>24</th>
#     <th>0.253238</th>
#     <th>0.251188</th>
#     <th>0.927000</th>
#   </tr>
#   <tr>
#     <th>25</th>
#     <th>0.252045</th>
#     <th>0.303878</th>
#     <th>0.902000</th>
#   </tr>
#   <tr>
#     <th>26</th>
#     <th>0.226175</th>
#     <th>0.247954</th>
#     <th>0.922000</th>
#   </tr>
#   <tr>
#     <th>27</th>
#     <th>0.234185</th>
#     <th>0.178239</th>
#     <th>0.945000</th>
#   </tr>
#   <tr>
#     <th>28</th>
#     <th>0.214235</th>
#     <th>0.212138</th>
#     <th>0.928000</th>
#   </tr>
#   <tr>
#     <th>29</th>
#     <th>0.223823</th>
#     <th>0.173304</th>
#     <th>0.948000</th>
#   </tr>
#   <tr>
#     <th>30</th>
#     <th>0.218181</th>
#     <th>0.167065</th>
#     <th>0.951000</th>
#   </tr>
#   <tr>
#     <th>31</th>
#     <th>0.172080</th>
#     <th>0.171915</th>
#     <th>0.947000</th>
#   </tr>
#   <tr>
#     <th>32</th>
#     <th>0.205593</th>
#     <th>0.157267</th>
#     <th>0.955000</th>
#   </tr>
#   <tr>
#     <th>33</th>
#     <th>0.160676</th>
#     <th>0.132733</th>
#     <th>0.958000</th>
#   </tr>
#   <tr>
#     <th>34</th>
#     <th>0.163551</th>
#     <th>0.140638</th>
#     <th>0.960000</th>
#   </tr>
#   <tr>
#     <th>35</th>
#     <th>0.169341</th>
#     <th>0.141757</th>
#     <th>0.953000</th>
#   </tr>
#   <tr>
#     <th>36</th>
#     <th>0.167990</th>
#     <th>0.144134</th>
#     <th>0.956000</th>
#   </tr>
#   <tr>
#     <th>37</th>
#     <th>0.153371</th>
#     <th>0.132449</th>
#     <th>0.958000</th>
#   </tr>
#   <tr>
#     <th>38</th>
#     <th>0.140030</th>
#     <th>0.132185</th>
#     <th>0.955000</th>
#   </tr>
#   <tr>
#     <th>39</th>
#     <th>0.139652</th>
#     <th>0.127335</th>
#     <th>0.958000</th>
#   </tr>
#   <tr>
#     <th>40</th>
#     <th>0.128910</th>
#     <th>0.119869</th>
#     <th>0.957000</th>
#   </tr>
#   <tr>
#     <th>41</th>
#     <th>0.137105</th>
#     <th>0.115044</th>
#     <th>0.959000</th>
#   </tr>
#   <tr>
#     <th>42</th>
#     <th>0.117215</th>
#     <th>0.125211</th>
#     <th>0.956000</th>
#   </tr>
#   <tr>
#     <th>43</th>
#     <th>0.110381</th>
#     <th>0.134482</th>
#     <th>0.956000</th>
#   </tr>
#   <tr>
#     <th>44</th>
#     <th>0.112782</th>
#     <th>0.127158</th>
#     <th>0.962000</th>
#   </tr>
#   <tr>
#     <th>45</th>
#     <th>0.101350</th>
#     <th>0.130077</th>
#     <th>0.956000</th>
#   </tr>
#   <tr>
#     <th>46</th>
#     <th>0.105704</th>
#     <th>0.119232</th>
#     <th>0.961000</th>
#   </tr>
#   <tr>
#     <th>47</th>
#     <th>0.096018</th>
#     <th>0.115482</th>
#     <th>0.960000</th>
#   </tr>
#   <tr>
#     <th>48</th>
#     <th>0.111375</th>
#     <th>0.117448</th>
#     <th>0.961000</th>
#   </tr>
#   <tr>
#     <th>49</th>
#     <th>0.098260</th>
#     <th>0.115705</th>
#     <th>0.963000</th>
#   </tr>
#   <tr>
#     <th>50</th>
#     <th>0.096428</th>
#     <th>0.117078</th>
#     <th>0.961000</th>
#   </tr>
# </table>

# %%
learner.save('stage-5')

# %%
learner.unfreeze()

# %%
learner.lr_find()
learner.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learner.fit_one_cycle(50,  6.25e-5)
# Out:
# Total time: 17:02 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.098613</th>
#     <th>0.123961</th>
#     <th>0.958000</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.098867</th>
#     <th>0.124462</th>
#     <th>0.959000</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.113486</th>
#     <th>0.170835</th>
#     <th>0.959000</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.095677</th>
#     <th>0.130262</th>
#     <th>0.960000</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.096900</th>
#     <th>0.108445</th>
#     <th>0.963000</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.120551</th>
#     <th>0.125395</th>
#     <th>0.956000</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.110078</th>
#     <th>0.125198</th>
#     <th>0.957000</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.133129</th>
#     <th>0.120570</th>
#     <th>0.963000</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.150394</th>
#     <th>0.150968</th>
#     <th>0.950000</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.129171</th>
#     <th>0.129208</th>
#     <th>0.959000</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>0.144264</th>
#     <th>0.154688</th>
#     <th>0.950000</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>0.132889</th>
#     <th>0.159200</th>
#     <th>0.952000</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>0.158280</th>
#     <th>0.143313</th>
#     <th>0.957000</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>0.143365</th>
#     <th>0.132587</th>
#     <th>0.965000</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>0.162806</th>
#     <th>0.166708</th>
#     <th>0.945000</th>
#   </tr>
#   <tr>
#     <th>16</th>
#     <th>0.134616</th>
#     <th>0.166920</th>
#     <th>0.953000</th>
#   </tr>
#   <tr>
#     <th>17</th>
#     <th>0.153319</th>
#     <th>0.130726</th>
#     <th>0.960000</th>
#   </tr>
#   <tr>
#     <th>18</th>
#     <th>0.121627</th>
#     <th>0.162536</th>
#     <th>0.946000</th>
#   </tr>
#   <tr>
#     <th>19</th>
#     <th>0.147319</th>
#     <th>0.155249</th>
#     <th>0.945000</th>
#   </tr>
#   <tr>
#     <th>20</th>
#     <th>0.114901</th>
#     <th>0.151198</th>
#     <th>0.954000</th>
#   </tr>
#   <tr>
#     <th>21</th>
#     <th>0.117454</th>
#     <th>0.113881</th>
#     <th>0.961000</th>
#   </tr>
#   <tr>
#     <th>22</th>
#     <th>0.121601</th>
#     <th>0.133560</th>
#     <th>0.958000</th>
#   </tr>
#   <tr>
#     <th>23</th>
#     <th>0.114039</th>
#     <th>0.114323</th>
#     <th>0.959000</th>
#   </tr>
#   <tr>
#     <th>24</th>
#     <th>0.100781</th>
#     <th>0.138993</th>
#     <th>0.956000</th>
#   </tr>
#   <tr>
#     <th>25</th>
#     <th>0.114487</th>
#     <th>0.143848</th>
#     <th>0.953000</th>
#   </tr>
#   <tr>
#     <th>26</th>
#     <th>0.084002</th>
#     <th>0.129109</th>
#     <th>0.955000</th>
#   </tr>
#   <tr>
#     <th>27</th>
#     <th>0.086504</th>
#     <th>0.135844</th>
#     <th>0.954000</th>
#   </tr>
#   <tr>
#     <th>28</th>
#     <th>0.082369</th>
#     <th>0.108729</th>
#     <th>0.969000</th>
#   </tr>
#   <tr>
#     <th>29</th>
#     <th>0.084196</th>
#     <th>0.136607</th>
#     <th>0.958000</th>
#   </tr>
#   <tr>
#     <th>30</th>
#     <th>0.083514</th>
#     <th>0.127231</th>
#     <th>0.959000</th>
#   </tr>
#   <tr>
#     <th>31</th>
#     <th>0.066504</th>
#     <th>0.116175</th>
#     <th>0.963000</th>
#   </tr>
#   <tr>
#     <th>32</th>
#     <th>0.071666</th>
#     <th>0.114355</th>
#     <th>0.958000</th>
#   </tr>
#   <tr>
#     <th>33</th>
#     <th>0.066022</th>
#     <th>0.111503</th>
#     <th>0.964000</th>
#   </tr>
#   <tr>
#     <th>34</th>
#     <th>0.063911</th>
#     <th>0.111765</th>
#     <th>0.961000</th>
#   </tr>
#   <tr>
#     <th>35</th>
#     <th>0.061721</th>
#     <th>0.133636</th>
#     <th>0.961000</th>
#   </tr>
#   <tr>
#     <th>36</th>
#     <th>0.051729</th>
#     <th>0.119326</th>
#     <th>0.965000</th>
#   </tr>
#   <tr>
#     <th>37</th>
#     <th>0.053169</th>
#     <th>0.111521</th>
#     <th>0.968000</th>
#   </tr>
#   <tr>
#     <th>38</th>
#     <th>0.051543</th>
#     <th>0.119640</th>
#     <th>0.965000</th>
#   </tr>
#   <tr>
#     <th>39</th>
#     <th>0.052498</th>
#     <th>0.116904</th>
#     <th>0.967000</th>
#   </tr>
#   <tr>
#     <th>40</th>
#     <th>0.041060</th>
#     <th>0.108436</th>
#     <th>0.964000</th>
#   </tr>
#   <tr>
#     <th>41</th>
#     <th>0.046535</th>
#     <th>0.115355</th>
#     <th>0.968000</th>
#   </tr>
#   <tr>
#     <th>42</th>
#     <th>0.036106</th>
#     <th>0.104066</th>
#     <th>0.967000</th>
#   </tr>
#   <tr>
#     <th>43</th>
#     <th>0.033993</th>
#     <th>0.107546</th>
#     <th>0.966000</th>
#   </tr>
#   <tr>
#     <th>44</th>
#     <th>0.030409</th>
#     <th>0.109755</th>
#     <th>0.965000</th>
#   </tr>
#   <tr>
#     <th>45</th>
#     <th>0.036438</th>
#     <th>0.112549</th>
#     <th>0.964000</th>
#   </tr>
#   <tr>
#     <th>46</th>
#     <th>0.034603</th>
#     <th>0.110401</th>
#     <th>0.965000</th>
#   </tr>
#   <tr>
#     <th>47</th>
#     <th>0.030934</th>
#     <th>0.109722</th>
#     <th>0.967000</th>
#   </tr>
#   <tr>
#     <th>48</th>
#     <th>0.033274</th>
#     <th>0.107454</th>
#     <th>0.968000</th>
#   </tr>
#   <tr>
#     <th>49</th>
#     <th>0.030418</th>
#     <th>0.109396</th>
#     <th>0.966000</th>
#   </tr>
#   <tr>
#     <th>50</th>
#     <th>0.033281</th>
#     <th>0.110757</th>
#     <th>0.970000</th>
#   </tr>
# </table>

# %%
learner.recorder.plot_losses()

# %%
learner.save('stage-6')

# %% [markdown]
# **Evaluation**

# %%
interp = ClassificationInterpretation.from_learner(learner)
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused()
# Out:
# [('02_STROMA', '03_COMPLEX', 3),
#  ('03_COMPLEX', '01_TUMOR', 3),
#  ('03_COMPLEX', '04_LYMPHO', 3),
#  ('04_LYMPHO', '03_COMPLEX', 3),
#  ('05_DEBRIS', '02_STROMA', 3),
#  ('03_COMPLEX', '02_STROMA', 2),
#  ('07_ADIPOSE', '08_EMPTY', 2),
#  ('08_EMPTY', '07_ADIPOSE', 2)]

# %%
preds, lb=learner.get_preds()

# %%
#  ROC curve
fpr, tpr, thresholds = roc_curve(lb.numpy(), preds.numpy()[:,1], pos_label=1)

#  ROC area
pred_score = auc(fpr, tpr)
print(f'ROC area is {pred_score}')
# Out:
# ROC area is 0.9982819194043987

# %%
plt.figure()
plt.plot(fpr, tpr, color='orange', label='ROC curve (area = %0.2f)' % pred_score)
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlim([-0.01, 1.0])
plt.ylim([0.0, 1.01])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
